# %%
# !pip install git+https://github.com/huggingface/diffusers
# !pip install accelerate wand
# !pip install -r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt
# Out:
# Collecting git+https://github.com/huggingface/diffusers
#   Cloning https://github.com/huggingface/diffusers to /tmp/pip-req-build-4gxlsdru
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/diffusers /tmp/pip-req-build-4gxlsdru
#   Resolved https://github.com/huggingface/diffusers to commit c1079f0887bec9a7d58f49001960febbbbd3f92b
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: importlib-metadata in /opt/conda/lib/python3.10/site-packages (from diffusers==0.30.0.dev0) (6.11.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from diffusers==0.30.0.dev0) (3.13.1)
# Collecting huggingface-hub>=0.23.2 (from diffusers==0.30.0.dev0)
#   Downloading huggingface_hub-0.24.5-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from diffusers==0.30.0.dev0) (1.24.3)
# Collecting regex!=2019.12.17 (from diffusers==0.30.0.dev0)
#   Downloading regex-2024.7.24-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 128.9 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from diffusers==0.30.0.dev0) (2.32.3)
# Collecting safetensors>=0.3.1 (from diffusers==0.30.0.dev0)
#   Downloading safetensors-0.4.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.10/site-packages (from diffusers==0.30.0.dev0) (10.2.0)
# Collecting fsspec>=2023.5.0 (from huggingface-hub>=0.23.2->diffusers==0.30.0.dev0)
#   Downloading fsspec-2024.6.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging>=20.9 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.23.2->diffusers==0.30.0.dev0) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.23.2->diffusers==0.30.0.dev0) (6.0.1)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.23.2->diffusers==0.30.0.dev0) (4.65.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.23.2->diffusers==0.30.0.dev0) (4.12.2)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.10/site-packages (from importlib-metadata->diffusers==0.30.0.dev0) (3.19.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->diffusers==0.30.0.dev0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->diffusers==0.30.0.dev0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->diffusers==0.30.0.dev0) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->diffusers==0.30.0.dev0) (2023.7.22)
# Downloading huggingface_hub-0.24.5-py3-none-any.whl (417 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.5/417.5 kB 872.1 kB/s eta 0:00:000:0100:01m
# Downloading regex-2024.7.24-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (776 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 776.5/776.5 kB 2.9 MB/s eta 0:00:0000:0100:01
# Downloading safetensors-0.4.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (435 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 435.5/435.5 kB 2.9 MB/s eta 0:00:00:00:01
# Downloading fsspec-2024.6.1-py3-none-any.whl (177 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.6/177.6 kB 1.3 MB/s eta 0:00:00:00:01
# Building wheels for collected packages: diffusers
#   Building wheel for diffusers (pyproject.toml) ... done
#   Created wheel for diffusers: filename=diffusers-0.30.0.dev0-py3-none-any.whl size=2630263 sha256=234f528c963949e97ac244e1523ed998675fbc06bb9281b67f05ddc087383d61
#   Stored in directory: /tmp/pip-ephem-wheel-cache-8tmj_dsr/wheels/f7/7d/99/d361489e5762e3464b3811bc629e94cf5bf5ef44dd5c3c4d52
# Successfully built diffusers
# Installing collected packages: safetensors, regex, fsspec, huggingface-hub, diffusers
# Successfully installed diffusers-0.30.0.dev0 fsspec-2024.6.1 huggingface-hub-0.24.5 regex-2024.7.24 safetensors-0.4.4
#
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Collecting accelerate
#   Downloading accelerate-0.33.0-py3-none-any.whl.metadata (18 kB)
# Collecting wand
#   Downloading Wand-0.6.13-py2.py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: numpy<2.0.0,>=1.17 in /opt/conda/lib/python3.10/site-packages (from accelerate) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from accelerate) (23.2)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from accelerate) (6.0.0)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /opt/conda/lib/python3.10/site-packages (from accelerate) (2.0.0+cu118)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /opt/conda/lib/python3.10/site-packages (from accelerate) (0.24.5)
# Requirement already satisfied: safetensors>=0.3.1 in /opt/conda/lib/python3.10/site-packages (from accelerate) (0.4.4)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.21.0->accelerate) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.21.0->accelerate) (2024.6.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.21.0->accelerate) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.21.0->accelerate) (4.65.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.21.0->accelerate) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (3.1.4)
# Requirement already satisfied: triton==2.0.0 in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (2.0.0)
# Requirement already satisfied: cmake in /opt/conda/lib/python3.10/site-packages (from triton==2.0.0->torch>=1.10.0->accelerate) (3.25.0)
# Requirement already satisfied: lit in /opt/conda/lib/python3.10/site-packages (from triton==2.0.0->torch>=1.10.0->accelerate) (15.0.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Downloading accelerate-0.33.0-py3-none-any.whl (315 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 315.1/315.1 kB 580.8 kB/s eta 0:00:0000:0100:01
# Downloading Wand-0.6.13-py2.py3-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.8/143.8 kB 673.6 kB/s eta 0:00:000:01
# Installing collected packages: wand, accelerate
# Successfully installed accelerate-0.33.0 wand-0.6.13
#
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: accelerate>=0.16.0 in /opt/conda/lib/python3.10/site-packages (from -r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 1)) (0.33.0)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.10/site-packages (from -r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 2)) (0.15.1+cu118)
# Collecting transformers>=4.25.1 (from -r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 3))
#   Downloading transformers-4.44.0-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 90.0 kB/s eta 0:00:00a 0:00:01
# Collecting datasets>=2.19.1 (from -r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 4))
#   Downloading datasets-2.20.0-py3-none-any.whl.metadata (19 kB)
# Collecting ftfy (from -r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 5))
#   Downloading ftfy-6.2.3-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: tensorboard in /opt/conda/lib/python3.10/site-packages (from -r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 6)) (2.13.0)
# Requirement already satisfied: Jinja2 in /opt/conda/lib/python3.10/site-packages (from -r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 7)) (3.1.4)
# Collecting peft==0.7.0 (from -r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 8))
#   Downloading peft-0.7.0-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from peft==0.7.0->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 8)) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from peft==0.7.0->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 8)) (23.2)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from peft==0.7.0->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 8)) (6.0.0)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from peft==0.7.0->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 8)) (6.0.1)
# Requirement already satisfied: torch>=1.13.0 in /opt/conda/lib/python3.10/site-packages (from peft==0.7.0->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 8)) (2.0.0+cu118)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from peft==0.7.0->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 8)) (4.65.0)
# Requirement already satisfied: safetensors in /opt/conda/lib/python3.10/site-packages (from peft==0.7.0->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 8)) (0.4.4)
# Requirement already satisfied: huggingface-hub>=0.17.0 in /opt/conda/lib/python3.10/site-packages (from peft==0.7.0->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 8)) (0.24.5)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from torchvision->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 2)) (2.32.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.10/site-packages (from torchvision->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 2)) (10.2.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.13.0->peft==0.7.0->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 8)) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch>=1.13.0->peft==0.7.0->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 8)) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.13.0->peft==0.7.0->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 8)) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.13.0->peft==0.7.0->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 8)) (3.3)
# Requirement already satisfied: triton==2.0.0 in /opt/conda/lib/python3.10/site-packages (from torch>=1.13.0->peft==0.7.0->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 8)) (2.0.0)
# Requirement already satisfied: cmake in /opt/conda/lib/python3.10/site-packages (from triton==2.0.0->torch>=1.13.0->peft==0.7.0->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 8)) (3.25.0)
# Requirement already satisfied: lit in /opt/conda/lib/python3.10/site-packages (from triton==2.0.0->torch>=1.13.0->peft==0.7.0->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 8)) (15.0.7)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.25.1->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 3)) (2024.7.24)
# Collecting tokenizers<0.20,>=0.19 (from transformers>=4.25.1->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 3))
#   Downloading tokenizers-0.19.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Collecting pyarrow>=15.0.0 (from datasets>=2.19.1->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 4))
#   Downloading pyarrow-17.0.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Collecting pyarrow-hotfix (from datasets>=2.19.1->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 4))
#   Downloading pyarrow_hotfix-0.6-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from datasets>=2.19.1->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 4)) (0.3.7)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from datasets>=2.19.1->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 4)) (2.2.0)
# Collecting tqdm (from peft==0.7.0->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 8))
#   Downloading tqdm-4.66.5-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 262.6 kB/s eta 0:00:00 0:00:01
# Collecting xxhash (from datasets>=2.19.1->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 4))
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess (from datasets>=2.19.1->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 4))
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.5.0,>=2023.1.0 (from fsspec[http]<=2024.5.0,>=2023.1.0->datasets>=2.19.1->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 4))
#   Downloading fsspec-2024.5.0-py3-none-any.whl.metadata (11 kB)
# Collecting aiohttp (from datasets>=2.19.1->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 4))
#   Downloading aiohttp-3.10.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.5 kB)
# Requirement already satisfied: wcwidth<0.3.0,>=0.2.12 in /opt/conda/lib/python3.10/site-packages (from ftfy->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 5)) (0.2.13)
# Requirement already satisfied: absl-py>=0.4 in /opt/conda/lib/python3.10/site-packages (from tensorboard->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 6)) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in /opt/conda/lib/python3.10/site-packages (from tensorboard->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 6)) (1.64.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /opt/conda/lib/python3.10/site-packages (from tensorboard->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 6)) (2.32.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /opt/conda/lib/python3.10/site-packages (from tensorboard->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 6)) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.10/site-packages (from tensorboard->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 6)) (3.6)
# Requirement already satisfied: protobuf>=3.19.6 in /opt/conda/lib/python3.10/site-packages (from tensorboard->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 6)) (4.25.3)
# Requirement already satisfied: setuptools>=41.0.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 6)) (70.3.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 6)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from tensorboard->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 6)) (3.0.3)
# Requirement already satisfied: wheel>=0.26 in /opt/conda/lib/python3.10/site-packages (from tensorboard->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 6)) (0.43.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from Jinja2->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 7)) (2.1.5)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp->datasets>=2.19.1->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 4))
#   Downloading aiohappyeyeballs-2.3.5-py3-none-any.whl.metadata (5.8 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp->datasets>=2.19.1->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 4))
#   Downloading aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets>=2.19.1->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 4)) (23.2.0)
# Collecting frozenlist>=1.1.1 (from aiohttp->datasets>=2.19.1->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 4))
#   Downloading frozenlist-1.4.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp->datasets>=2.19.1->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 4))
#   Downloading multidict-6.0.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp->datasets>=2.19.1->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 4))
#   Downloading yarl-1.9.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (31 kB)
# Collecting async-timeout<5.0,>=4.0 (from aiohttp->datasets>=2.19.1->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 4))
#   Downloading async_timeout-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 6)) (5.4.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 6)) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 6)) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 6)) (2.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 2)) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 2)) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 2)) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 2)) (2023.7.22)
# Collecting dill<0.3.9,>=0.3.0 (from datasets>=2.19.1->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 4))
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets>=2.19.1->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 4)) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets>=2.19.1->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 4)) (2023.4)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets>=2.19.1->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 4)) (2024.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /opt/conda/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 6)) (0.6.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets>=2.19.1->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 4)) (1.16.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 6)) (3.2.2)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.13.0->peft==0.7.0->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 8)) (1.3.0)
# Downloading peft-0.7.0-py3-none-any.whl (168 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.3/168.3 kB 541.7 kB/s eta 0:00:00 0:00:01m
# Downloading transformers-4.44.0-py3-none-any.whl (9.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 10.0 MB/s eta 0:00:0000:0100:01
# Downloading datasets-2.20.0-py3-none-any.whl (547 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 547.8/547.8 kB 3.4 MB/s eta 0:00:00:00:01
# Downloading ftfy-6.2.3-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.0/43.0 kB 356.2 kB/s eta 0:00:00 0:00:01
# Downloading fsspec-2024.5.0-py3-none-any.whl (316 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.1/316.1 kB 3.1 MB/s eta 0:00:00ta 0:00:01
# Downloading aiohttp-3.10.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 5.1 MB/s eta 0:00:00:00:01
# Downloading pyarrow-17.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (39.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 4.0 MB/s eta 0:00:00:00:0100:01
# Downloading tokenizers-0.19.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 7.9 MB/s eta 0:00:00:00:0100:01
# Downloading tqdm-4.66.5-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 450.7 kB/s eta 0:00:00 0:00:01
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 1.3 MB/s eta 0:00:00:00:01
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 579.5 kB/s eta 0:00:00a 0:00:01
# Downloading pyarrow_hotfix-0.6-py3-none-any.whl (7.9 kB)
# Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 1.1 MB/s eta 0:00:00ta 0:00:01
# Downloading aiohappyeyeballs-2.3.5-py3-none-any.whl (12 kB)
# Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Downloading async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Downloading frozenlist-1.4.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (239 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.5/239.5 kB 251.2 kB/s eta 0:00:0000:01
# Downloading multidict-6.0.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (124 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.3/124.3 kB 544.4 kB/s eta 0:00:0000:01
# Downloading yarl-1.9.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (301 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.6/301.6 kB 3.5 MB/s eta 0:00:00:00:01
# Installing collected packages: xxhash, tqdm, pyarrow-hotfix, pyarrow, multidict, ftfy, fsspec, frozenlist, dill, async-timeout, aiohappyeyeballs, yarl, multiprocess, aiosignal, tokenizers, aiohttp, transformers, datasets, peft
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.65.0
#     Uninstalling tqdm-4.65.0:
#       Successfully uninstalled tqdm-4.65.0
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 12.0.1
#     Uninstalling pyarrow-12.0.1:
#       Successfully uninstalled pyarrow-12.0.1
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.6.1
#     Uninstalling fsspec-2024.6.1:
#       Successfully uninstalled fsspec-2024.6.1
#   Attempting uninstall: dill
#     Found existing installation: dill 0.3.7
#     Uninstalling dill-0.3.7:
#       Successfully uninstalled dill-0.3.7
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mlflow 2.6.0 requires pyarrow<13,>=4.0.0, but you have pyarrow 17.0.0 which is incompatible.
# Successfully installed aiohappyeyeballs-2.3.5 aiohttp-3.10.2 aiosignal-1.3.1 async-timeout-4.0.3 datasets-2.20.0 dill-0.3.8 frozenlist-1.4.1 fsspec-2024.5.0 ftfy-6.2.3 multidict-6.0.5 multiprocess-0.70.16 peft-0.7.0 pyarrow-17.0.0 pyarrow-hotfix-0.6 tokenizers-0.19.1 tqdm-4.66.5 transformers-4.44.0 xxhash-3.4.1 yarl-1.9.4
#
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install wandb
# Out:
# Collecting wandb
#   Downloading wandb-0.17.6-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /opt/conda/lib/python3.10/site-packages (from wandb) (8.1.7)
# Collecting docker-pycreds>=0.4.0 (from wandb)
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (3.1.43)
# Requirement already satisfied: platformdirs in /opt/conda/lib/python3.10/site-packages (from wandb) (4.2.2)
# Requirement already satisfied: protobuf!=4.21.0,<6,>=3.19.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (4.25.3)
# Requirement already satisfied: psutil>=5.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (6.0.0)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from wandb) (6.0.1)
# Requirement already satisfied: requests<3,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (2.32.3)
# Collecting sentry-sdk>=1.0.0 (from wandb)
#   Downloading sentry_sdk-2.12.0-py2.py3-none-any.whl.metadata (9.8 kB)
# Collecting setproctitle (from wandb)
#   Downloading setproctitle-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.9 kB)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from wandb) (70.3.0)
# Requirement already satisfied: six>=1.4.0 in /opt/conda/lib/python3.10/site-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (2023.7.22)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.0)
# Downloading wandb-0.17.6-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 5.0 MB/s eta 0:00:0000:0100:010m
# Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Downloading sentry_sdk-2.12.0-py2.py3-none-any.whl (301 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.8/301.8 kB 1.9 MB/s eta 0:00:00:00:01
# Downloading setproctitle-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Installing collected packages: setproctitle, sentry-sdk, docker-pycreds, wandb
# Successfully installed docker-pycreds-0.4.0 sentry-sdk-2.12.0 setproctitle-1.3.3 wandb-0.17.6
#
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
import wandb
import torch
from diffusers import StableDiffusionPipeline, DPMSolverMultistepScheduler, AutoPipelineForText2Image
from huggingface_hub import model_info
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# 2024-08-09 17:58:56.440012: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-08-09 17:59:02.461009: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Definindo as variáveis diretamente no script Python
MODEL_NAME="runwayml/stable-diffusion-v1-5"
OUTPUT_DIR="./finetune_lora/pokemon"
HUB_MODEL_ID="pokemon-lora"
DATASET_NAME="svjack/pokemon-blip-captions-en-zh"

# Criando o diretório de saída
# !mkdir -p $OUTPUT_DIR

# Executando o treinamento com o `accelerate launch`
# !accelerate launch --mixed_precision="bf16" train_text_to_image_lora.py \
  --pretrained_model_name_or_path=$MODEL_NAME \
  --dataset_name=$DATASET_NAME \
  --dataloader_num_workers=8 \
  --resolution=512 \
  --center_crop \
  --random_flip \
  --train_batch_size=1 \
  --gradient_accumulation_steps=4 \
  --max_train_steps=15000 \
  --learning_rate=1e-04 \
  --max_grad_norm=1 \
  --lr_scheduler="cosine" \
  --lr_warmup_steps=0 \
  --output_dir=$OUTPUT_DIR \
  --checkpointing_steps=500 \
  --caption_column="en_text" \
  --validation_prompt="A pokemon with blue eyes." \
  --seed=1337
# Out:
# The following values were not passed to `accelerate launch` and had defaults used instead:
# 	`--num_processes` was set to a value of `1`
# 	`--num_machines` was set to a value of `1`
# 	`--dynamo_backend` was set to a value of `'no'`
# To avoid this warning pass in values for each of the problematic parameters or run `accelerate config`.
# /opt/conda/bin/python3.10: can't open file '/home/jovyan/local/Fine Tuning/LoRa/train_text_to_image_lora.py': [Errno 2] No such file or directory
# Traceback (most recent call last):
#   File "/opt/conda/bin/accelerate", line 8, in <module>
#     sys.exit(main())
#   File "/opt/conda/lib/python3.10/site-packages/accelerate/commands/accelerate_cli.py", line 48, in main
#     args.func(args)
#   File "/opt/conda/lib/python3.10/site-packages/accelerate/commands/launch.py", line 1106, in launch_command
#     simple_launcher(args)
#   File "/opt/conda/lib/python3.10/site-packages/accelerate/commands/launch.py", line 704, in simple_launcher
#     raise subprocess.CalledProcessError(returncode=process.returncode, cmd=cmd)
# subprocess.CalledProcessError: Command '['/opt/conda/bin/python3.10', 'train_text_to_image_lora.py', '--pretrained_model_name_or_path=runwayml/stable-diffusion-v1-5', '--dataset_name=svjack/pokemon-blip-captions-en-zh', '--dataloader_num_workers=8', '--resolution=512', '--center_crop', '--random_flip', '--train_batch_size=1', '--gradient_accumulation_steps=4', '--max_train_steps=15000', '--learning_rate=1e-04', '--max_grad_norm=1', '--lr_scheduler=cosine', '--lr_warmup_steps=0', '--output_dir=./finetune_lora/pokemon', '--checkpointing_steps=500', '--caption_column=en_text', '--validation_prompt=A pokemon with blue eyes.', '--seed=1337']' returned non-zero exit status 2.
